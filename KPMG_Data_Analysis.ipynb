# %% [markdown]
# <a href="https://colab.research.google.com/github/Mingyang0816/KPMG-Data-Analytics/blob/main/KPMG_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Datasets

# %%
# Authenticate Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import all 4 datasets
import pandas as pd

file_path = '/content/drive/My Drive/KPMG_Data_Analysis/KPMG_Dataset.xlsx'
transactions_df = pd.read_excel(file_path, 'Transactions')
customer_list_df = pd.read_excel(file_path, 'NewCustomerList')
demographic_df = pd.read_excel(file_path, 'CustomerDemographic')
address_df = pd.read_excel(file_path, 'CustomerAddress')

# %% [markdown]
# #Transactions Dataset

# %%
# Change header to top row
new_header = transactions_df.iloc[0]
transactions_df = transactions_df[1:]
transactions_df.columns = new_header
transactions_df.head()
# Out:
# 0 transaction_id product_id customer_id     transaction_date online_order  \
# 1              1          2        2950  2017-02-25 00:00:00        False
# 2              2          3        3120  2017-05-21 00:00:00         True
# 3              3         37         402  2017-10-16 00:00:00        False
# 4              4         88        3135  2017-08-31 00:00:00        False
# 5              5         78         787  2017-10-01 00:00:00         True
#
# 0 order_status           brand product_line product_class product_size  \
# 1     Approved           Solex     Standard        medium       medium
# 2     Approved   Trek Bicycles     Standard        medium        large
# 3     Approved      OHM Cycles     Standard           low       medium
# 4     Approved  Norco Bicycles     Standard        medium       medium
# 5     Approved  Giant Bicycles     Standard        medium        large
#
# 0 list_price standard_cost product_first_sold_date
# 1      71.49         53.62                   41245
# 2    2091.47        388.92                   41701
# 3    1793.43        248.82                   36361
# 4    1198.46         381.1                   36145
# 5     1765.3        709.48                   42226

# %% [markdown]
# ###Summary of Data

# %%
# Summary of info
transactions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 1 to 20000
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  object
#  1   product_id               20000 non-null  object
#  2   customer_id              20000 non-null  object
#  3   transaction_date         20000 non-null  object
#  4   online_order             19640 non-null  object
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  object
#  11  standard_cost            19803 non-null  object
#  12  product_first_sold_date  19803 non-null  object
# dtypes: object(13)
# memory usage: 2.0+ MB

# %%
# Statistical summary
transactions_df.describe()
# Out:
# 0       transaction_id  product_id  customer_id     transaction_date  \
# count            20000       20000        20000                20000
# unique           20000         101         3494                  364
# top                  1           0         2183  2017-02-14 00:00:00
# freq                 1        1378           14                   82
#
# 0      online_order order_status  brand product_line product_class  \
# count         19640        20000  19803        19803         19803
# unique            2            2      6            4             3
# top            True     Approved  Solex     Standard        medium
# freq           9829        19821   4253        14176         13826
#
# 0      product_size  list_price  standard_cost  product_first_sold_date
# count         19803    20000.00       19803.00                    19803
# unique            3      296.00         103.00                      100
# top          medium     2091.47         388.92                    33879
# freq          12990      465.00         465.00                      234

# %% [markdown]
# ###Missing & Duplicate Values

# %%
# Check number of missing values
transactions_df.isnull().sum()
# Out:
# 0
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
# Find all rows of data with missing values
null_values = transactions_df[transactions_df.isna().any(axis = 1)]
null_values.shape[0]
null_values
# Out:
# 0     transaction_id product_id customer_id     transaction_date online_order  \
# 98                98         49         333  2017-06-23 00:00:00          NaN
# 137              137          0         431  2017-09-23 00:00:00        False
# 160              160          0        3300  2017-08-27 00:00:00        False
# 167              167         90        3177  2017-04-26 00:00:00          NaN
# 170              170          6         404  2017-10-16 00:00:00          NaN
# ...              ...        ...         ...                  ...          ...
# 19636          19636         98        1389  2017-07-26 00:00:00          NaN
# 19794          19794          0        2860  2017-01-13 00:00:00        False
# 19844          19844          3           8  2017-01-28 00:00:00          NaN
# 19860          19860          0        2468  2017-06-24 00:00:00         True
# 19872          19872          0          61  2017-03-17 00:00:00         True
#
# 0     order_status           brand product_line product_class product_size  \
# 98        Approved   Trek Bicycles         Road        medium       medium
# 137       Approved             NaN          NaN           NaN          NaN
# 160       Approved             NaN          NaN           NaN          NaN
# 167       Approved  Norco Bicycles     Standard           low       medium
# 170       Approved      OHM Cycles     Standard          high       medium
# ...            ...             ...          ...           ...          ...
# 19636     Approved   Trek Bicycles     Standard          high       medium
# 19794     Approved             NaN          NaN           NaN          NaN
# 19844     Approved   Trek Bicycles     Standard        medium        large
# 19860     Approved             NaN          NaN           NaN          NaN
# 19872     Approved             NaN          NaN           NaN          NaN
#
# 0     list_price standard_cost product_first_sold_date
# 98        533.51        400.13                   37823
# 137      1942.61           NaN                     NaN
# 160      1656.86           NaN                     NaN
# 167       363.01        290.41                   38482
# 170       227.88        136.73                   37838
# ...          ...           ...                     ...
# 19636     358.39        215.03                   38002
# 19794     868.56           NaN                     NaN
# 19844    2091.47        388.92                   37823
# 19860    1497.43           NaN                     NaN
# 19872     867.92           NaN                     NaN
#
# [555 rows x 13 columns]

# %%
# Check number of duplicate values
transactions_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###Values in each column

# %%
transactions_df.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object', name=0)

# %%
transactions_df["online_order"].value_counts()
# Out:
# True     9829
# False    9811
# Name: online_order, dtype: int64

# %%
transactions_df["order_status"].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
transactions_df["brand"].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
transactions_df["product_line"].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
transactions_df["product_class"].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
transactions_df["product_size"].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %%
transactions_df["list_price"].value_counts()
# Out:
# 2091.47    465
# 1403.50    396
# 71.49      274
# 1231.15    235
# 1890.39    233
#           ...
# 56.21        1
# 126.36       1
# 1300.96      1
# 1697.27      1
# 867.92       1
# Name: list_price, Length: 296, dtype: int64

# %%
transactions_df["standard_cost"].value_counts()
# Out:
# 388.920000    465
# 954.820000    396
# 53.620000     274
# 161.600000    235
# 260.140000    233
#              ...
# 151.960000    124
# 206.350000    114
# 312.735016      1
# 270.299988      1
# 667.400024      1
# Name: standard_cost, Length: 103, dtype: int64

# %%
# Retrieve non-null values in standard_cost column
new_df = transactions_df[transactions_df['standard_cost'].notnull()]

# Calculate decimal places for each standard_cost value
new_df['decimals'] = new_df['standard_cost'].map(lambda x: str(x).split('.')[1]).apply(len)

# Find rows with standard_cost value of more than 2 decimal places
new_df['decimals'].astype(int)
new_df[new_df['decimals'] > 2]
# Out:
# <ipython-input-225-2839a78c1891>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['decimals'] = new_df['standard_cost'].map(lambda x: str(x).split('.')[1]).apply(len)
# 0     transaction_id product_id customer_id     transaction_date online_order  \
# 8708            8708          0        5034  2017-10-07 00:00:00        False
# 16701          16701          0        5034  2017-01-27 00:00:00        False
# 17469          17469          0        5034  2017-01-03 00:00:00        False
#
# 0     order_status           brand product_line product_class product_size  \
# 8708      Approved           Solex         Road        medium       medium
# 16701     Approved  Norco Bicycles     Standard        medium       medium
# 17469     Approved      OHM Cycles         Road        medium       medium
#
# 0     list_price standard_cost product_first_sold_date  decimals
# 8708      416.98    312.735016                   42218         7
# 16701      360.4    270.299988                   35667         7
# 17469     742.54    667.400024                   33879         7

# %% [markdown]
# **The "standard_cost" column contains decimals with more than 2 decimal places, which definitely cannot be a value for cost.**

# %%
transactions_df["product_first_sold_date"].value_counts()
# Out:
# 33879    234
# 41064    229
# 37823    227
# 39880    222
# 38216    220
#         ...
# 41848    169
# 42404    168
# 41922    166
# 37659    163
# 34586    162
# Name: product_first_sold_date, Length: 100, dtype: int64

# %% [markdown]
# **The "product_first_sold_date" column contains integers instead of datetime values.**

# %% [markdown]
# #Customer Demographic Dataset

# %%
# Change header to top row
new_header = demographic_df.iloc[0]
demographic_df = demographic_df[1:]
demographic_df.columns = new_header
demographic_df.head()
# Out:
# 0 customer_id      first_name  last_name  gender  \
# 1           1         Laraine  Medendorp       F
# 2           2             Eli    Bockman    Male
# 3           3           Arlin     Dearle    Male
# 4           4          Talbot        NaN    Male
# 5           5  Sheila-kathryn     Calton  Female
#
# 0 past_3_years_bike_related_purchases                  DOB  \
# 1                                  93  1953-10-12 00:00:00
# 2                                  81  1980-12-16 00:00:00
# 3                                  61  1954-01-20 00:00:00
# 4                                  33  1961-10-03 00:00:00
# 5                                  56  1977-05-13 00:00:00
#
# 0               job_title job_industry_category     wealth_segment  \
# 1     Executive Secretary                Health      Mass Customer
# 2  Administrative Officer    Financial Services      Mass Customer
# 3      Recruiting Manager              Property      Mass Customer
# 4                     NaN                    IT      Mass Customer
# 5           Senior Editor                   NaN  Affluent Customer
#
# 0 deceased_indicator                                            default  \
# 1                  N                                                 "'
# 2                  N                       <script>alert('hi')</script>
# 3                  N                                2018-02-01 00:00:00
# 4                  N  () { _; } >_[$($())] { touch /tmp/blns.shellsh...
# 5                  N                                                NIL
#
# 0 owns_car tenure
# 1      Yes     11
# 2      Yes     16
# 3      Yes     15
# 4       No      7
# 5      Yes      8

# %% [markdown]
# ###Summary of Data

# %%
# Summary of info
demographic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 1 to 4000
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   object
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   object
#  5   DOB                                  3913 non-null   object
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
#  11  owns_car                             4000 non-null   object
#  12  tenure                               3913 non-null   object
# dtypes: object(13)
# memory usage: 406.4+ KB

# %%
# Statistical summary
demographic_df.describe()
# Out:
# 0       customer_id first_name last_name  gender  \
# count          4000       4000      3875    4000
# unique         4000       3139      3725       6
# top               1        Max  Pristnor  Female
# freq              1          5         3    2037
#
# 0       past_3_years_bike_related_purchases                  DOB  \
# count                                  4000                 3913
# unique                                  100                 3448
# top                                      16  1978-01-30 00:00:00
# freq                                     56                    7
#
# 0                                  job_title job_industry_category  \
# count                                   3494                  3344
# unique                                   195                     9
# top     Business Systems Development Analyst         Manufacturing
# freq                                      45                   799
#
# 0      wealth_segment deceased_indicator  default owns_car  tenure
# count            4000               4000     3698     4000    3913
# unique              3                  2       90        2      22
# top     Mass Customer                  N      100      Yes       7
# freq             2000               3998      113     2024     235

# %% [markdown]
# ###Missing and Duplicate Values

# %%
# Check number of missing values
demographic_df.isnull().sum()
# Out:
# 0
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
# Find all rows of data with missing values
null_values = demographic_df[demographic_df.isna().any(axis = 1)]
null_values.shape[0]
null_values
# Out:
# 0    customer_id      first_name  last_name  gender  \
# 4              4          Talbot        NaN    Male
# 5              5  Sheila-kathryn     Calton  Female
# 6              6            Curr  Duckhouse    Male
# 7              7            Fina     Merali  Female
# 8              8             Rod      Inder    Male
# ...          ...             ...        ...     ...
# 3986        3986          Oralle   Petrello  Female
# 3987        3987          Beckie    Wakeham  Female
# 3998        3998          Sarene    Woolley       U
# 3999        3999       Patrizius        NaN    Male
# 4000        4000           Kippy    Oldland    Male
#
# 0    past_3_years_bike_related_purchases                  DOB  \
# 4                                     33  1961-10-03 00:00:00
# 5                                     56  1977-05-13 00:00:00
# 6                                     35  1966-09-16 00:00:00
# 7                                      6  1976-02-23 00:00:00
# 8                                     31  1962-03-30 00:00:00
# ...                                  ...                  ...
# 3986                                   1  1976-12-01 00:00:00
# 3987                                  18  1964-05-29 00:00:00
# 3998                                  60                  NaN
# 3999                                  11  1973-10-24 00:00:00
# 4000                                  76  1991-11-05 00:00:00
#
# 0                job_title job_industry_category     wealth_segment  \
# 4                      NaN                    IT      Mass Customer
# 5            Senior Editor                   NaN  Affluent Customer
# 6                      NaN                Retail     High Net Worth
# 7                      NaN    Financial Services  Affluent Customer
# 8          Media Manager I                   NaN      Mass Customer
# ...                    ...                   ...                ...
# 3986         Social Worker                Health      Mass Customer
# 3987                   NaN           Argiculture      Mass Customer
# 3998     Assistant Manager                    IT     High Net Worth
# 3999                   NaN         Manufacturing  Affluent Customer
# 4000  Software Engineer IV                   NaN  Affluent Customer
#
# 0    deceased_indicator                                            default  \
# 4                     N  () { _; } >_[$($())] { touch /tmp/blns.shellsh...
# 5                     N                                                NIL
# 6                     N                                           ðµ ð ð ð
# 7                     N                                          â°â´âµâââ
# 8                     N                            (â¯Â°â¡Â°ï¼â¯ï¸µ â»ââ»)
# ...                 ...                                                ...
# 3986                  N                                                NaN
# 3987                  N                                                  á
# 3998                  N                                                NaN
# 3999                  N                             Â¡â¢Â£Â¢âÂ§Â¶â¢ÂªÂºââ
# 4000                  N                                                0/0
#
# 0    owns_car tenure
# 4          No      7
# 5         Yes      8
# 6         Yes     13
# 7         Yes     11
# 8          No      7
# ...       ...    ...
# 3986       No     21
# 3987       No      7
# 3998       No    NaN
# 3999      Yes     10
# 4000       No     11
#
# [1370 rows x 13 columns]

# %%
# Check number of duplicate values
demographic_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###Values in each column

# %%
demographic_df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object', name=0)

# %%
demographic_df['first_name'].value_counts()
# Out:
# Max         5
# Tobe        5
# Timmie      5
# Kippy       4
# Pail        4
#            ..
# Katy        1
# Hakim       1
# Fanchon     1
# Jeanette    1
# Sarene      1
# Name: first_name, Length: 3139, dtype: int64

# %%
demographic_df['last_name'].value_counts()
# Out:
# Pristnor     3
# Ramsdell     3
# Eager        2
# Zisneros     2
# Dredge       2
#             ..
# Whittock     1
# Carwithen    1
# Blas         1
# Dearlove     1
# Oldland      1
# Name: last_name, Length: 3725, dtype: int64

# %%
demographic_df['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# F            1
# Femal        1
# M            1
# Name: gender, dtype: int64

# %% [markdown]
# **The "gender" column contains multiple expressions with the same meaning, such as Female, Femal and F, which can all be grouped under Female.**

# %%
# Replace values with same meaning
demographic_df['gender'] = demographic_df['gender'].replace(["F", "Femal"], "Female")
demographic_df['gender'] = demographic_df['gender'].replace(["M"], "Male")

# %%
demographic_df['gender'].value_counts()
# Out:
# Female    2039
# Male      1873
# U           88
# Name: gender, dtype: int64

# %%
demographic_df['past_3_years_bike_related_purchases'].value_counts()
# Out:
# 16    56
# 19    56
# 67    54
# 20    54
# 2     50
#       ..
# 8     28
# 95    27
# 85    27
# 86    27
# 92    24
# Name: past_3_years_bike_related_purchases, Length: 100, dtype: int64

# %%
demographic_df['DOB'].value_counts()
# Out:
# 1978-01-30    7
# 1964-07-08    4
# 1962-12-17    4
# 1978-08-19    4
# 1977-05-13    4
#              ..
# 1989-06-16    1
# 1998-09-30    1
# 1985-03-11    1
# 1989-10-23    1
# 1991-11-05    1
# Name: DOB, Length: 3448, dtype: int64

# %%
# Find rows with earliest Date of Birth
demographic_df['DOB'] = pd.to_datetime(demographic_df['DOB'])
demographic_df.sort_values(by="DOB", inplace = True)
demographic_df.head()
# Out:
# 0    customer_id first_name last_name  gender  \
# 34            34   Jephthah  Bachmann       U
# 720          720     Darrel     Canet    Male
# 1092        1092     Katlin   Creddon  Female
# 3410        3410    Merrili   Brittin  Female
# 2413        2413      Abbey    Murrow    Male
#
# 0    past_3_years_bike_related_purchases        DOB                 job_title  \
# 34                                    59 1843-12-21           Legal Assistant
# 720                                   67 1931-10-23        Recruiting Manager
# 1092                                  56 1935-08-22        VP Quality Control
# 3410                                  93 1940-09-22                       NaN
# 2413                                  27 1943-08-11  Environmental Specialist
#
# 0    job_industry_category     wealth_segment deceased_indicator  \
# 34                      IT  Affluent Customer                  N
# 720                 Retail  Affluent Customer                  N
# 1092                Retail      Mass Customer                  N
# 3410              Property      Mass Customer                  N
# 2413         Manufacturing     High Net Worth                  N
#
# 0                default owns_car tenure
# 34                   NaN       No     20
# 720   1;DROP TABLE users       No      6
# 1092  ì¬íê³¼íì ì´íì°êµ¬ì       No      5
# 3410                   á       No     16
# 2413                  á       Yes     17

# %% [markdown]
# **The "DOB" column contains an outlier, since a person born in 1843 will be 180 years old now, which is not feasible.**

# %%
demographic_df['job_title'].value_counts()
# Out:
# Business Systems Development Analyst    45
# Social Worker                           44
# Tax Accountant                          44
# Internal Auditor                        42
# Recruiting Manager                      41
#                                         ..
# Human Resources Assistant IV             4
# Research Assistant III                   3
# Health Coach I                           3
# Health Coach III                         3
# Developer I                              1
# Name: job_title, Length: 195, dtype: int64

# %%
demographic_df['job_industry_category'].value_counts()
# Out:
# Manufacturing         799
# Financial Services    774
# Health                602
# Retail                358
# Property              267
# IT                    223
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: job_industry_category, dtype: int64

# %%
demographic_df['wealth_segment'].value_counts()
# Out:
# Mass Customer        2000
# High Net Worth       1021
# Affluent Customer     979
# Name: wealth_segment, dtype: int64

# %%
demographic_df['deceased_indicator'].value_counts()
# Out:
# N    3998
# Y       2
# Name: deceased_indicator, dtype: int64

# %%
demographic_df['default'].value_counts()
# Out:
# 100                                       113
# 1                                         112
# -1                                        111
# -100                                       99
# â°â´âµâââ                                  53
#                                          ...
# <img src=x onerror=alert('hi') />          31
# /dev/null; touch /tmp/blns.fail ; echo     30
# âªâªtestâª                                 29
# ì¸ëë°í ë¥´                                 27
# ,ãã»:*:ã»ãâ( â» Ï â» )ãã»:*:ã»ãâ           25
# Name: default, Length: 90, dtype: int64

# %% [markdown]
# **The "Default" column contains a bunch of gibberish values, hence it should be deleted.**

# %%
demographic_df['owns_car'].value_counts()
# Out:
# Yes    2024
# No     1976
# Name: owns_car, dtype: int64

# %%
demographic_df['tenure'].value_counts()
# Out:
# 7     235
# 5     228
# 11    221
# 10    218
# 16    215
# 8     211
# 18    208
# 12    202
# 14    200
# 9     200
# 6     192
# 13    191
# 4     191
# 17    182
# 15    179
# 1     166
# 3     160
# 19    159
# 2     150
# 20     96
# 22     55
# 21     54
# Name: tenure, dtype: int64

# %% [markdown]
# #Customer Address Dataset

# %%
# Change header to top row
new_header = address_df.iloc[0]
address_df = address_df[1:]
address_df.columns = new_header
address_df.head()
# Out:
# 0 customer_id              address postcode            state    country  \
# 1           1   060 Morning Avenue     2016  New South Wales  Australia
# 2           2  6 Meadow Vale Court     2153  New South Wales  Australia
# 3           4   0 Holy Cross Court     4211              QLD  Australia
# 4           5  17979 Del Mar Point     2448  New South Wales  Australia
# 5           6     9 Oakridge Court     3216              VIC  Australia
#
# 0 property_valuation
# 1                 10
# 2                 10
# 3                  9
# 4                  4
# 5                  9

# %% [markdown]
# ### Summary of Data

# %%
# Summary of info
address_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 1 to 3999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   object
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   object
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   object
# dtypes: object(6)
# memory usage: 187.6+ KB

# %%
# Statistical summary
address_df.describe()
# Out:
# 0       customer_id                  address  postcode state    country  \
# count          3999                     3999      3999  3999       3999
# unique         3999                     3996       873     5          1
# top               1  3 Mariners Cove Terrace      2170   NSW  Australia
# freq              1                        2        31  2054       3999
#
# 0       property_valuation
# count                 3999
# unique                  12
# top                      9
# freq                   647

# %% [markdown]
# ### Missing and Duplicate Values

# %%
# Check number of missing values
address_df.isnull().sum()
# Out:
# 0
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
# Check number of duplicate values
address_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Values in each column

# %%
address_df.columns
# Out:
# Index(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object', name=0)

# %%
address_df['state'].value_counts()
# Out:
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: state, dtype: int64

# %% [markdown]
# **The "state" column contains multiple expressions with the same meaning, such as NSW and New South Wales, which can all be grouped under NSW.**

# %%
# Replace values with same meaning
address_df['state'] = address_df['state'].replace("New South Wales", "NSW")
address_df['state'] = address_df['state'].replace("Victoria", "VIC")

# %%
address_df['state'].value_counts()
# Out:
# NSW    2140
# VIC    1021
# QLD     838
# Name: state, dtype: int64

# %%
address_df['country'].value_counts()
# Out:
# Australia    3999
# Name: country, dtype: int64

# %%
address_df['property_valuation'].value_counts()
# Out:
# 9     647
# 8     646
# 10    577
# 7     493
# 11    281
# 6     238
# 5     225
# 4     214
# 12    195
# 3     186
# 1     154
# 2     143
# Name: property_valuation, dtype: int64
